# %%
import matplotlib.pyplot as plt
import math

# %%
average_rgb = 0.9740130692 * 100
average_grey = 0.9511455615 * 100
average_rf = 0.968683623 * 100
average_dt = 0.8809948692 * 100

median_rgb = 0.982681 * 100
median_grey = 0.9731505 * 100
median_rf = 0.980952 * 100
median_dt = 0.8934675 * 100

min_rgb = 0.867769 * 100
min_grey = 0.490385 * 100
min_rf = 0.770833 * 100
min_dt = 0.574467 * 100

# %%
min_fig = plt.figure()
min_ax = min_fig.add_axes([0,0,1,1])
min_ax.set_title('Min. Youdens Index')
min_labels = ["Grey", "RGB MLP", "RGB Random Forest", "RGB Decision Tree"]
min_values = [min_grey, min_rgb, min_rf, min_dt]
min_ax.bar(min_labels,min_values)
min_ax.set_ylim([0, 100])
plt.ylabel("Youdens Index in %")
plt.show()

# %%
median_fig = plt.figure()
median_ax = median_fig.add_axes([0,0,1,1])
median_ax.set_title('Median Youdens Index')

median_labels = ["Grey", "RGB MLP", "RGB Random Forest", "RGB Decision Tree"]
median_values = [median_grey, median_rgb, median_rf, median_dt]
median_ax.bar(median_labels,median_values)
median_ax.set_ylim([0, 100])
plt.ylabel("Youdens Index in %")
plt.show()

# %%
average_fig = plt.figure()
average_ax = average_fig.add_axes([0,0,1,1])
average_ax.set_title('Average Youdens Index')

average_labels = ["Grey", "RGB MLP", "RGB Random Forest", "RGB Decision Tree"]
average_values = [average_grey, average_rgb, average_rf, average_dt]
average_ax.bar(average_labels, average_values)
average_ax.set_ylim([0, 100])
plt.ylabel("Youdens Index in %")
plt.show()
